# %%
# !pip install numpy pandas matplotlib seaborn

# %%
import pandas as pd;
import matplotlib.pyplot as plt
nyc = pd.read_csv("NYPD_Complaint_Data_Historic.csv", low_memory=False);

# %%
nyc.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   325341655   02/11/2015     15:00:00          NaN          NaN
# 1   393816841   03/17/2012     10:30:00   03/17/2012     11:00:00
# 2   802896158   10/27/2016     13:48:00   11/03/2016     13:49:00
# 3   633812343   11/27/2014     19:00:00   11/27/2014     22:30:00
# 4   300349533   12/11/2013     13:30:00   12/11/2013     14:15:00
#
#    ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  PD_CD  ...  \
# 0         73.0  02/11/2015    359  OFFENSES AGAINST PUBLIC ADMINI  749.0  ...
# 1         69.0  03/17/2012    344    ASSAULT 3 & RELATED OFFENSES  114.0  ...
# 2         71.0  11/03/2016    578                   HARRASSMENT 2  638.0  ...
# 3        112.0  11/28/2014    104                            RAPE  157.0  ...
# 4         24.0  12/12/2013    109                   GRAND LARCENY  438.0  ...
#
#   SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# ...

# %%
nyc.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'ADDR_PCT_CD', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD',
#        'PD_DESC', 'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM',
#        'LOC_OF_OCCUR_DESC', 'PREM_TYP_DESC', 'JURIS_DESC', 'JURISDICTION_CODE',
#        'PARKS_NM', 'HADEVELOPT', 'HOUSING_PSA', 'X_COORD_CD', 'Y_COORD_CD',
#        'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT',
#        'Latitude', 'Longitude', 'Lat_Lon', 'PATROL_BORO', 'STATION_NAME',
#        'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX'],
#       dtype='object')

# %%
nyc.shape
# Out:
# (6521496, 35)

# %%
nyc.describe()
# Out:
#          CMPLNT_NUM   ADDR_PCT_CD         KY_CD         PD_CD  \
# count  6.521496e+06  6.519330e+06  6.521496e+06  6.515950e+06
# mean   5.500495e+08  6.334742e+01  2.950517e+02  4.158455e+02
# std    2.597726e+08  3.446469e+01  1.494424e+02  2.181323e+02
# min    1.000001e+08  1.000000e+00  1.010000e+02  1.010000e+02
# 25%    3.252088e+08  4.000000e+01  1.170000e+02  2.540000e+02
# 50%    5.499982e+08  6.300000e+01  3.410000e+02  3.880000e+02
# 75%    7.749884e+08  9.400000e+01  3.510000e+02  6.370000e+02
# max    9.999999e+08  1.230000e+02  8.810000e+02  9.750000e+02
#
#        JURISDICTION_CODE    X_COORD_CD    Y_COORD_CD  TRANSIT_DISTRICT  \
# count       6.515950e+06  6.497432e+06  6.497432e+06     144928.000000
# mean        7.166550e-01  1.004770e+06  2.069971e+05         13.623627
# std         6.640506e+00  2.178932e+04  3.163962e+04         12.472158
# min         0.000000e+00  1.110000e+02  1.110000e+02          1.000000
# ...

# %%
nyc['OFNS_DESC']
# Out:
# 0          OFFENSES AGAINST PUBLIC ADMINI
# 1            ASSAULT 3 & RELATED OFFENSES
# 2                           HARRASSMENT 2
# 3                                    RAPE
# 4                           GRAND LARCENY
#                         ...
# 6521491      ASSAULT 3 & RELATED OFFENSES
# 6521492     OFF. AGNST PUB ORD SENSBLTY &
# 6521493    CRIMINAL MISCHIEF & RELATED OF
# 6521494                            FRAUDS
# 6521495    GRAND LARCENY OF MOTOR VEHICLE
# Name: OFNS_DESC, Length: 6521496, dtype: object

# %%
nyc.loc[3]
# Out:
# CMPLNT_NUM                               633812343
# CMPLNT_FR_DT                            11/27/2014
# CMPLNT_FR_TM                              19:00:00
# CMPLNT_TO_DT                            11/27/2014
# CMPLNT_TO_TM                              22:30:00
# ADDR_PCT_CD                                  112.0
# RPT_DT                                  11/28/2014
# KY_CD                                          104
# OFNS_DESC                                     RAPE
# PD_CD                                        157.0
# PD_DESC                                     RAPE 1
# CRM_ATPT_CPTD_CD                         COMPLETED
# LAW_CAT_CD                                  FELONY
# BORO_NM                                     QUEENS
# LOC_OF_OCCUR_DESC                           INSIDE
# PREM_TYP_DESC               RESIDENCE - APT. HOUSE
# JURIS_DESC                        N.Y. POLICE DEPT
# JURISDICTION_CODE                              0.0
# ...

# %%
nyc['STATION_NAME']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 6521491    NaN
# 6521492    NaN
# 6521493    NaN
# 6521494    NaN
# 6521495    NaN
# Name: STATION_NAME, Length: 6521496, dtype: object

# %%
nyc.dropna()
# Out:
# Empty DataFrame
# Columns: [CMPLNT_NUM, CMPLNT_FR_DT, CMPLNT_FR_TM, CMPLNT_TO_DT, CMPLNT_TO_TM, ADDR_PCT_CD, RPT_DT, KY_CD, OFNS_DESC, PD_CD, PD_DESC, CRM_ATPT_CPTD_CD, LAW_CAT_CD, BORO_NM, LOC_OF_OCCUR_DESC, PREM_TYP_DESC, JURIS_DESC, JURISDICTION_CODE, PARKS_NM, HADEVELOPT, HOUSING_PSA, X_COORD_CD, Y_COORD_CD, SUSP_AGE_GROUP, SUSP_RACE, SUSP_SEX, TRANSIT_DISTRICT, Latitude, Longitude, Lat_Lon, PATROL_BORO, STATION_NAME, VIC_AGE_GROUP, VIC_RACE, VIC_SEX]
# Index: []
#
# [0 rows x 35 columns]

# %%
nyc['STATION_NAME']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 6521491    NaN
# 6521492    NaN
# 6521493    NaN
# 6521494    NaN
# 6521495    NaN
# Name: STATION_NAME, Length: 6521496, dtype: object

# %%
nyc.loc[3]
# Out:
# CMPLNT_NUM                               633812343
# CMPLNT_FR_DT                            11/27/2014
# CMPLNT_FR_TM                              19:00:00
# CMPLNT_TO_DT                            11/27/2014
# CMPLNT_TO_TM                              22:30:00
# ADDR_PCT_CD                                  112.0
# RPT_DT                                  11/28/2014
# KY_CD                                          104
# OFNS_DESC                                     RAPE
# PD_CD                                        157.0
# PD_DESC                                     RAPE 1
# CRM_ATPT_CPTD_CD                         COMPLETED
# LAW_CAT_CD                                  FELONY
# BORO_NM                                     QUEENS
# LOC_OF_OCCUR_DESC                           INSIDE
# PREM_TYP_DESC               RESIDENCE - APT. HOUSE
# JURIS_DESC                        N.Y. POLICE DEPT
# JURISDICTION_CODE                              0.0
# ...

# %%
nyc.isna().sum()
# Out:
# CMPLNT_NUM                 0
# CMPLNT_FR_DT             655
# CMPLNT_FR_TM              48
# CMPLNT_TO_DT         1610377
# CMPLNT_TO_TM         1606068
# ADDR_PCT_CD             2166
# RPT_DT                     0
# KY_CD                      0
# OFNS_DESC              18813
# PD_CD                   5546
# PD_DESC                 5546
# CRM_ATPT_CPTD_CD           7
# LAW_CAT_CD                 0
# BORO_NM                10568
# LOC_OF_OCCUR_DESC    1397087
# PREM_TYP_DESC          37862
# JURIS_DESC                 0
# JURISDICTION_CODE       5546
# PARKS_NM             6500476
# HADEVELOPT           6197046
# HOUSING_PSA          6017708
# X_COORD_CD             24064
# Y_COORD_CD             24064
# SUSP_AGE_GROUP       4598163
# SUSP_RACE            3229622
# SUSP_SEX             3362936
# TRANSIT_DISTRICT     6376568
# Latitude               24064
# Longitude              24064
# Lat_Lon                24064
# PATROL_BORO             6003
# STATION_NAME         6376568
# ...

# %%
len(nyc)
# Out:
# 6521496

# %%
nyc = nyc.dropna(axis=0)

# %%
len(nyc)
# Out:
# 0

# %%
nyc = pd.read_csv("NYPD_Complaint_Data_Historic.csv", low_memory=False);

# %%
len(nyc)
# Out:
# 6521496

# %%
nyc.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   325341655   02/11/2015     15:00:00          NaN          NaN
# 1   393816841   03/17/2012     10:30:00   03/17/2012     11:00:00
# 2   802896158   10/27/2016     13:48:00   11/03/2016     13:49:00
# 3   633812343   11/27/2014     19:00:00   11/27/2014     22:30:00
# 4   300349533   12/11/2013     13:30:00   12/11/2013     14:15:00
#
#    ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  PD_CD  ...  \
# 0         73.0  02/11/2015    359  OFFENSES AGAINST PUBLIC ADMINI  749.0  ...
# 1         69.0  03/17/2012    344    ASSAULT 3 & RELATED OFFENSES  114.0  ...
# 2         71.0  11/03/2016    578                   HARRASSMENT 2  638.0  ...
# 3        112.0  11/28/2014    104                            RAPE  157.0  ...
# 4         24.0  12/12/2013    109                   GRAND LARCENY  438.0  ...
#
#   SUSP_SEX TRANSIT_DISTRICT   Latitude  Longitude  \
# ...

# %%
del nyc['CMPLNT_TO_DT'];
#deleting column. Ending date for occurrence
#note: I know this column is potentially useful, but since there are many null values in the columns, I think its better to delete. 
#For the purposes of project 1, I think it would be acceptable to just work on initial reported dates/times, and not use the ending date/time
#of the occurrences

# %%
nyc.head()
#checking if column is successfully deleted
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_TM  ADDR_PCT_CD      RPT_DT  \
# 0   325341655   02/11/2015     15:00:00          NaN         73.0  02/11/2015
# 1   393816841   03/17/2012     10:30:00     11:00:00         69.0  03/17/2012
# 2   802896158   10/27/2016     13:48:00     13:49:00         71.0  11/03/2016
# 3   633812343   11/27/2014     19:00:00     22:30:00        112.0  11/28/2014
# 4   300349533   12/11/2013     13:30:00     14:15:00         24.0  12/12/2013
#
#    KY_CD                       OFNS_DESC  PD_CD  \
# 0    359  OFFENSES AGAINST PUBLIC ADMINI  749.0
# 1    344    ASSAULT 3 & RELATED OFFENSES  114.0
# 2    578                   HARRASSMENT 2  638.0
# 3    104                            RAPE  157.0
# 4    109                   GRAND LARCENY  438.0
#
#                                              PD_DESC  ... SUSP_SEX  \
# 0                     VIOLATION OF ORDER OF PROTECTI  ...        M
# 1                                OBSTR BREATH/CIRCUL  ...      NaN
# ...

# %%
del nyc['CMPLNT_TO_TM'];
#deleting column. Ending time for occurrence

# %%
nyc.iloc[0]
#checking if column deleted
#We have a lot more to delete..
# Out:
# CMPLNT_NUM                                325341655
# CMPLNT_FR_DT                             02/11/2015
# CMPLNT_FR_TM                               15:00:00
# ADDR_PCT_CD                                    73.0
# RPT_DT                                   02/11/2015
# KY_CD                                           359
# OFNS_DESC            OFFENSES AGAINST PUBLIC ADMINI
# PD_CD                                         749.0
# PD_DESC              VIOLATION OF ORDER OF PROTECTI
# CRM_ATPT_CPTD_CD                          COMPLETED
# LAW_CAT_CD                              MISDEMEANOR
# BORO_NM                                    BROOKLYN
# LOC_OF_OCCUR_DESC                            INSIDE
# PREM_TYP_DESC            RESIDENCE - PUBLIC HOUSING
# JURIS_DESC                      N.Y. HOUSING POLICE
# JURISDICTION_CODE                               2.0
# PARKS_NM                                        NaN
# HADEVELOPT                                   TILDEN
# ...

# %%
del nyc['PARKS_NM'];
#Name of the park/playground where occurrences are reported

# %%
del nyc['HADEVELOPT'];
#Name of housing development

# %%
del nyc['ADDR_PCT_CD'];
#Number of the precinct of the incident

# %%
del nyc['LOC_OF_OCCUR_DESC'];
#specific location of occurrence i.e. inside/outside/front/behind location

# %%
del nyc['JURISDICTION_CODE'];
#jurisdiction responsible for event i.e. police/housing/transit

# %%
del nyc['HOUSING_PSA'];
#development level code

# %%
del nyc['Latitude'];
#self explanatory

# %%
del nyc['Longitude'];
#self explanatory

# %%
del nyc['Lat_Lon'];
#self explanatory

# %%
del nyc['STATION_NAME'];
#transit station name

# %%
nyc.head()
#just checking to see if nothing is broken
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM      RPT_DT  KY_CD  \
# 0   325341655   02/11/2015     15:00:00  02/11/2015    359
# 1   393816841   03/17/2012     10:30:00  03/17/2012    344
# 2   802896158   10/27/2016     13:48:00  11/03/2016    578
# 3   633812343   11/27/2014     19:00:00  11/28/2014    104
# 4   300349533   12/11/2013     13:30:00  12/12/2013    109
#
#                         OFNS_DESC  PD_CD  \
# 0  OFFENSES AGAINST PUBLIC ADMINI  749.0
# 1    ASSAULT 3 & RELATED OFFENSES  114.0
# 2                   HARRASSMENT 2  638.0
# 3                            RAPE  157.0
# 4                   GRAND LARCENY  438.0
#
#                                              PD_DESC CRM_ATPT_CPTD_CD  \
# 0                     VIOLATION OF ORDER OF PROTECTI        COMPLETED
# 1                                OBSTR BREATH/CIRCUL        COMPLETED
# 2                              HARASSMENT,SUBD 3,4,5        COMPLETED
# 3                                             RAPE 1        COMPLETED
# ...

# %%
del nyc['X_COORD_CD']
#x coordinate in NY State coordinate system

# %%
del nyc['Y_COORD_CD']
#y coordinate in NY State coordinate system

# %%
del nyc['TRANSIT_DISTRICT']
#transit district number

# %%
nyc.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM      RPT_DT  KY_CD  \
# 0   325341655   02/11/2015     15:00:00  02/11/2015    359
# 1   393816841   03/17/2012     10:30:00  03/17/2012    344
# 2   802896158   10/27/2016     13:48:00  11/03/2016    578
# 3   633812343   11/27/2014     19:00:00  11/28/2014    104
# 4   300349533   12/11/2013     13:30:00  12/12/2013    109
#
#                         OFNS_DESC  PD_CD  \
# 0  OFFENSES AGAINST PUBLIC ADMINI  749.0
# 1    ASSAULT 3 & RELATED OFFENSES  114.0
# 2                   HARRASSMENT 2  638.0
# 3                            RAPE  157.0
# 4                   GRAND LARCENY  438.0
#
#                                              PD_DESC CRM_ATPT_CPTD_CD  \
# 0                     VIOLATION OF ORDER OF PROTECTI        COMPLETED
# 1                                OBSTR BREATH/CIRCUL        COMPLETED
# 2                              HARASSMENT,SUBD 3,4,5        COMPLETED
# 3                                             RAPE 1        COMPLETED
# ...

# %%
#We now have 20 columns, down from 35.
#Because this data set is huge, there are still null values in the data. I still want to try to work with what we have.
nyc.shape
# Out:
# (6521496, 20)

# %%
nyc.isna().sum()

#SUSP columns still have lots of null values. I may delete this later after I play around with the data.
# Out:
# CMPLNT_NUM                0
# CMPLNT_FR_DT            655
# CMPLNT_FR_TM             48
# RPT_DT                    0
# KY_CD                     0
# OFNS_DESC             18813
# PD_CD                  5546
# PD_DESC                5546
# CRM_ATPT_CPTD_CD          7
# LAW_CAT_CD                0
# BORO_NM               10568
# PREM_TYP_DESC         37862
# JURIS_DESC                0
# SUSP_AGE_GROUP      4598163
# SUSP_RACE           3229622
# SUSP_SEX            3362936
# PATROL_BORO            6003
# VIC_AGE_GROUP       1638441
# VIC_RACE                305
# VIC_SEX                 304
# dtype: int64

# %%
#Now lets see what we can do besides butcher the data..

#lets see how many reports are considered to be a felony
nyc[nyc['LAW_CAT_CD'] == 'FELONY']
#okay, 2007248 rows. That's a surprising amount of felonies..
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM      RPT_DT  KY_CD  \
# 3         633812343   11/27/2014     19:00:00  11/28/2014    104
# 4         300349533   12/11/2013     13:30:00  12/12/2013    109
# 10        450452011   10/21/2012     00:30:00  10/21/2012    106
# 17        198456325   07/27/2015     02:55:00  07/27/2015    109
# 20        896725438   10/20/2015     14:00:00  10/20/2015    107
# ...             ...          ...          ...         ...    ...
# 6521482   614795871   01/14/2018     02:50:00  01/14/2018    106
# 6521483   176160896   05/29/2018     19:15:00  05/29/2018    109
# 6521488   120248300   09/11/2018     22:30:00  09/11/2018    111
# 6521493   146134182   08/03/2018     22:30:00  08/04/2018    121
# 6521495   176655779   11/15/2018     10:00:00  04/11/2019    110
#
#                               OFNS_DESC  PD_CD  \
# 3                                  RAPE  157.0
# 4                         GRAND LARCENY  438.0
# ...

# %%
nyc['LAW_CAT_CD'].unique()
#just checking what to see if there aren't any values I didn't expect.
# Out:
# array(['MISDEMEANOR', 'VIOLATION', 'FELONY'], dtype=object)

# %%
nyc['OFNS_DESC'].unique()
#Let's see a unique list of all the offense descriptions.
# Out:
# array(['OFFENSES AGAINST PUBLIC ADMINI', 'ASSAULT 3 & RELATED OFFENSES',
#        'HARRASSMENT 2', 'RAPE', 'GRAND LARCENY', 'PETIT LARCENY',
#        'OFF. AGNST PUB ORD SENSBLTY &', 'CRIMINAL TRESPASS',
#        'CRIMINAL MISCHIEF & RELATED OF', 'FELONY ASSAULT', 'SEX CRIMES',
#        'DANGEROUS DRUGS', 'BURGLARY', 'DANGEROUS WEAPONS', 'THEFT-FRAUD',
#        'ROBBERY', 'MISCELLANEOUS PENAL LAW',
#        'GRAND LARCENY OF MOTOR VEHICLE', 'INTOXICATED & IMPAIRED DRIVING',
#        'OTHER OFFENSES RELATED TO THEF', 'POSSESSION OF STOLEN PROPERTY',
#        'VEHICLE AND TRAFFIC LAWS', 'MURDER & NON-NEGL. MANSLAUGHTER',
#        'UNAUTHORIZED USE OF A VEHICLE', 'THEFT OF SERVICES',
#        'NYS LAWS-UNCLASSIFIED FELONY', 'OFFENSES INVOLVING FRAUD',
#        'FORGERY', 'ADMINISTRATIVE CODE', 'GAMBLING', 'FRAUDS', 'ARSON',
#        'OFFENSES AGAINST THE PERSON', nan, 'OFFENSES RELATED TO CHILDREN',
#        'PETIT LARCENY OF MOTOR VEHICLE', 'DISORDERLY CONDUCT',
# ...

# %%
nyc['OFNS_DESC'].value_counts()
# Out:
# PETIT LARCENY                       1076048
# HARRASSMENT 2                        808638
# ASSAULT 3 & RELATED OFFENSES         678378
# CRIMINAL MISCHIEF & RELATED OF       652192
# GRAND LARCENY                        564483
#                                      ...
# OTHER STATE LAWS (NON PENAL LAW)         10
# ABORTION                                  7
# UNDER THE INFLUENCE OF DRUGS              3
# OFFENSES AGAINST MARRIAGE UNCL            3
# KIDNAPPING AND RELATED OFFENSES           2
# Name: OFNS_DESC, Length: 70, dtype: int64

# %%
#Petty larceny is highest reported crime in New York; followed by harassment

# %%
import datetime

# %%
nyc['RPT_DT'] = pd.to_datetime(nyc['RPT_DT'])
#converting date strings to date objects
#'RPT_DT is the date the event was reported to the police'
#other dates in the data were not able to be converted to date object. couldn't figure out a solution quickly enough.

# %%
nyc['MONTH'] = nyc['RPT_DT'].dt.month_name()
#Creating a new column for month

# %%
nyc['MONTH']
#Checking for month
# Out:
# 0          February
# 1             March
# 2          November
# 3          November
# 4          December
#              ...
# 6521491    December
# 6521492       April
# 6521493      August
# 6521494       April
# 6521495       April
# Name: MONTH, Length: 6521496, dtype: object

# %%
nyc['MONTH']
# Out:
# 0           2
# 1           3
# 2          11
# 3          11
# 4          12
#            ..
# 6521491    12
# 6521492     4
# 6521493     8
# 6521494     4
# 6521495     4
# Name: MONTH, Length: 6521496, dtype: int64

# %%
nyc.loc[1, 'RPT_DT'].day_name()
#testing if conversion worked

# %%
nyc['YEAR'] = nyc.RPT_DT.dt.year
#creating a new column for the dataset for year reported

# %%
nyc['HOUR'] = pd.to_datetime(nyc['CMPLNT_FR_TM']).dt.hour

# %%
nyc.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM     RPT_DT  \
# 0   325341655   02/11/2015     15:00:00          NaN          NaN 2015-02-11
# 1   393816841   03/17/2012     10:30:00   03/17/2012     11:00:00 2012-03-17
# 2   802896158   10/27/2016     13:48:00   11/03/2016     13:49:00 2016-11-03
# 3   633812343   11/27/2014     19:00:00   11/27/2014     22:30:00 2014-11-28
# 4   300349533   12/11/2013     13:30:00   12/11/2013     14:15:00 2013-12-12
#
#    KY_CD                       OFNS_DESC  PD_CD  \
# 0    359  OFFENSES AGAINST PUBLIC ADMINI  749.0
# 1    344    ASSAULT 3 & RELATED OFFENSES  114.0
# 2    578                   HARRASSMENT 2  638.0
# 3    104                            RAPE  157.0
# 4    109                   GRAND LARCENY  438.0
#
#                                              PD_DESC  ... SUSP_AGE_GROUP  \
# 0                     VIOLATION OF ORDER OF PROTECTI  ...          25-44
# ...

# %%
nyc['BORO_NM'].value_counts()
#Brooklyn has the highest count of reported crimes.
# Out:
# BROOKLYN         1940965
# MANHATTAN        1563118
# BRONX            1412192
# QUEENS           1286683
# STATEN ISLAND     307970
# Name: BORO_NM, dtype: int64

# %%
nyc['SUSP_RACE'].value_counts()
# Out:
# BLACK                             1228439
# UNKNOWN                            852962
# WHITE HISPANIC                     560527
# WHITE                              368060
# BLACK HISPANIC                     168902
# ASIAN / PACIFIC ISLANDER           102726
# AMERICAN INDIAN/ALASKAN NATIVE      10247
# OTHER                                  11
# Name: SUSP_RACE, dtype: int64

# %%
nyc['VIC_RACE'].value_counts()
# Out:
# UNKNOWN                           2192171
# BLACK                             1549254
# WHITE                             1133929
# WHITE HISPANIC                    1039709
# ASIAN / PACIFIC ISLANDER           361605
# BLACK HISPANIC                     214983
# AMERICAN INDIAN/ALASKAN NATIVE      29509
# OTHER                                  31
# Name: VIC_RACE, dtype: int64

# %%
nyc['VIC_SEX'].value_counts()
# Out:
# F    2549714
# M    2127077
# E    1069215
# D     775182
# U          4
# Name: VIC_SEX, dtype: int64

# %%
import seaborn as sns

# %%
sns.scatterplot(data=nyc, x='YEAR', y='OFNS_DESC', hue='BORO_NM')

#Not really useful, just seeing if it works
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='OFNS_DESC'>

# %%
sns.set(rc={"figure.figsize":(35,20)})
#resizing figure size

# %%
sns.scatterplot(data=nyc, x='YEAR', y='OFNS_DESC')
#more readable but still small, given all the different types of offenses. graph is not useful
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='OFNS_DESC'>

# %%
sns.set(rc={"figure.figsize":(20,12)})
ax = sns.distplot(nyc['YEAR'], bins='auto', kde=False)
ax= plt.gca()
ax.set_title("Number of Crimes Per Year 2006-2017")
#With this graph, you can see that crime rate has declined slightly since 2006.
# Out:
# C:\Users\agpju\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Number of Crimes Per Year 2006-2017')

# %%
sns.set(rc={"figure.figsize":(20,12)})

ax = sns.countplot(nyc['BORO_NM'])
plt.ticklabel_format(style='plain', axis='y')
ax= plt.gca()
ax.set_title("Number of Crimes Per Borough Years 2006-2017")
#Brooklyn has the highest crime rate out of all the boroughs
# Out:
# C:\Users\agpju\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Crimes Per Borough Years 2006-2017')

# %%
sns.set(rc={"figure.figsize":(15,9)})
sns.countplot(nyc['RPT_DT'].dt.day_name())
plt.ticklabel_format(style='plain', axis='y')
ax= plt.gca()
ax.set_title("Number of Crimes on Days, Years 2006-2017")
# Out:
# C:\Users\agpju\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Crimes on Days, Years 2006-2017')

# %%
sns.set(rc={"figure.figsize":(40,25)})
ax = sns.lineplot(data=nyc, x='OFNS_DESC', y='YEAR', hue='BORO_NM')
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
#X label is missing, not useful at all
# Out:
# C:\Users\agpju\AppData\Local\Temp\ipykernel_107308\1141924434.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
# [Text(0, 0, ''),
#  Text(1, 0, ''),
#  Text(2, 0, ''),
#  Text(3, 0, ''),
#  Text(4, 0, ''),
#  Text(5, 0, ''),
#  Text(6, 0, ''),
#  Text(7, 0, ''),
#  Text(8, 0, ''),
#  Text(9, 0, ''),
#  Text(10, 0, ''),
#  Text(11, 0, ''),
#  Text(12, 0, ''),
#  Text(13, 0, ''),
#  Text(14, 0, ''),
#  Text(15, 0, ''),
#  Text(16, 0, ''),
#  Text(17, 0, ''),
#  Text(18, 0, ''),
#  Text(19, 0, ''),
#  Text(20, 0, ''),
#  Text(21, 0, ''),
#  Text(22, 0, ''),
#  Text(23, 0, ''),
#  Text(24, 0, ''),
#  Text(25, 0, ''),
#  Text(26, 0, ''),
#  Text(27, 0, ''),
#  Text(28, 0, ''),
#  Text(29, 0, ''),
#  Text(30, 0, ''),
#  Text(31, 0, ''),
#  Text(32, 0, ''),
#  Text(33, 0, ''),
#  Text(34, 0, ''),
#  Text(35, 0, ''),
#  Text(36, 0, ''),
#  Text(37, 0, ''),
#  Text(38, 0, ''),
#  Text(39, 0, ''),
# ...

# %%
crime_filter = nyc['OFNS_DESC']
crime_filter
# Out:
# 0          OFFENSES AGAINST PUBLIC ADMINI
# 1            ASSAULT 3 & RELATED OFFENSES
# 2                           HARRASSMENT 2
# 3                                    RAPE
# 4                           GRAND LARCENY
#                         ...
# 6521491      ASSAULT 3 & RELATED OFFENSES
# 6521492     OFF. AGNST PUB ORD SENSBLTY &
# 6521493    CRIMINAL MISCHIEF & RELATED OF
# 6521494                            FRAUDS
# 6521495    GRAND LARCENY OF MOTOR VEHICLE
# Name: OFNS_DESC, Length: 6521496, dtype: object

# %%
nyc_filter = nyc[nyc['OFNS_DESC'] != 'nan']

# %%
nyc_filter
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         325341655   02/11/2015     15:00:00          NaN          NaN
# 1         393816841   03/17/2012     10:30:00   03/17/2012     11:00:00
# 2         802896158   10/27/2016     13:48:00   11/03/2016     13:49:00
# 3         633812343   11/27/2014     19:00:00   11/27/2014     22:30:00
# 4         300349533   12/11/2013     13:30:00   12/11/2013     14:15:00
# ...             ...          ...          ...          ...          ...
# 6521491   225471008   12/02/2018     04:15:00   12/02/2018     04:17:00
# 6521492   368441925   01/20/2018     00:08:00   04/26/2019     12:00:00
# 6521493   146134182   08/03/2018     22:30:00   08/04/2018     06:30:00
# 6521494   763119484   12/10/2018     11:00:00   12/21/2018     15:00:00
# 6521495   176655779   11/15/2018     10:00:00   03/23/2019     15:00:00
#
#             RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# ...

# %%
crime_count = nyc_filter.groupby(['OFNS_DESC']).size()
crime_count
# Out:
# OFNS_DESC
# ABORTION                                    7
# ADMINISTRATIVE CODE                     14317
# ADMINISTRATIVE CODES                       19
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED      492
# ALCOHOLIC BEVERAGE CONTROL LAW           1092
#                                         ...
# THEFT-FRAUD                             71499
# UNAUTHORIZED USE OF A VEHICLE           19109
# UNDER THE INFLUENCE OF DRUGS                3
# UNLAWFUL POSS. WEAP. ON SCHOOL             65
# VEHICLE AND TRAFFIC LAWS                78781
# Length: 70, dtype: int64

# %%
crime_count.plot(kind="bar")
plt.ticklabel_format(style='plain', axis='y')

# %%
nyc.head()
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM     RPT_DT  \
# 0   325341655   02/11/2015     15:00:00          NaN          NaN 2015-02-11
# 1   393816841   03/17/2012     10:30:00   03/17/2012     11:00:00 2012-03-17
# 2   802896158   10/27/2016     13:48:00   11/03/2016     13:49:00 2016-11-03
# 3   633812343   11/27/2014     19:00:00   11/27/2014     22:30:00 2014-11-28
# 4   300349533   12/11/2013     13:30:00   12/11/2013     14:15:00 2013-12-12
#
#    KY_CD                       OFNS_DESC  PD_CD  \
# 0    359  OFFENSES AGAINST PUBLIC ADMINI  749.0
# 1    344    ASSAULT 3 & RELATED OFFENSES  114.0
# 2    578                   HARRASSMENT 2  638.0
# 3    104                            RAPE  157.0
# 4    109                   GRAND LARCENY  438.0
#
#                                              PD_DESC  ...  \
# 0                     VIOLATION OF ORDER OF PROTECTI  ...
# 1                                OBSTR BREATH/CIRCUL  ...
# ...

# %%
crime_category_count = nyc_filter.groupby(['LAW_CAT_CD']).size()
crime_category_count
# Out:
# LAW_CAT_CD
# FELONY         2007248
# MISDEMEANOR    3691965
# VIOLATION       822283
# dtype: int64

# %%
plot = crime_category_count.plot(kind='bar')
ax= plt.gca()
ax.set_title("Counts of Misdemeanors per Hour of Day")
# Out:
# Text(0.5, 1.0, 'Counts of Misdemeanors per Hour of Day')

# %%
nyc_filter = nyc[nyc['OFNS_DESC'] != 'nan']

# %%
sns.countplot(x='MONTH', data=nyc_filter)
# Tried to sort the month, but couldn't get it to work.
# Out:
# <AxesSubplot:xlabel='MONTH', ylabel='count'>

# %%
plot = sns.countplot(x='HOUR', data=nyc_filter)
ax= plt.gca()
ax.set_title("Counts of Reported Crimes per Hour of Day")
# Out:
# Text(0.5, 1.0, 'Counts of Reported Crimes per Hour of Day')

# %%
plot = sns.countplot(x='HOUR', data=nyc[nyc['LAW_CAT_CD'] == 'MISDEMEANOR'])
ax= plt.gca()
ax.set_title("Counts of Misdemeanors per Hour of Day")
#Time distribution for Misdemeanors
# Out:
# Text(0.5, 1.0, 'Counts of Misdemeanors per Hour of Day')

# %%
plot = sns.countplot(x='HOUR', data=nyc[nyc['LAW_CAT_CD'] == 'FELONY'])
ax= plt.gca()
ax.set_title("Counts of Reported Crimes per Hour of Day")
#Time distribution for Felonies
# Out:
# Text(0.5, 1.0, 'Counts of Reported Crimes per Hour of Day')

# %%
plot = sns.countplot(x='HOUR', data=nyc[nyc['LAW_CAT_CD'] == 'VIOLATION'])
ax= plt.gca()
ax.set_title("Counts of Reported Crimes per Hour of Day")
#Time distribution for Violations
# Out:
# Text(0.5, 1.0, 'Counts of Reported Crimes per Hour of Day')

# %%
brooklyn_filter = nyc[nyc['BORO_NM'] == 'BROOKLYN']

# %%
brooklyn_filter.columns
# Out:
# Index(['CMPLNT_NUM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM', 'CMPLNT_TO_DT',
#        'CMPLNT_TO_TM', 'RPT_DT', 'KY_CD', 'OFNS_DESC', 'PD_CD', 'PD_DESC',
#        'CRM_ATPT_CPTD_CD', 'LAW_CAT_CD', 'BORO_NM', 'PREM_TYP_DESC',
#        'JURIS_DESC', 'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX', 'PATROL_BORO',
#        'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX', 'YEAR', 'MONTH', 'HOUR'],
#       dtype='object')

# %%
brooklyn_OFNS = brooklyn_filter.groupby(['OFNS_DESC']).size().sort_values(ascending=False)
brooklyn_OFNS
# Out:
# OFNS_DESC
# PETIT LARCENY                       298935
# HARRASSMENT 2                       242688
# ASSAULT 3 & RELATED OFFENSES        213392
# CRIMINAL MISCHIEF & RELATED OF      201938
# GRAND LARCENY                       149664
#                                      ...
# LOITERING                                6
# ADMINISTRATIVE CODES                     4
# OTHER STATE LAWS (NON PENAL LAW)         3
# LOITERING FOR DRUG PURPOSES              3
# ABORTION                                 1
# Length: 64, dtype: int64

# %%
sns.set(rc={"figure.figsize":(20,20)})
ax = sns.countplot(data=brooklyn_filter, x=brooklyn_filter['OFNS_DESC'])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax= plt.gca()
ax.set_title("Occurrences of Crimes Committed in Brooklyn 2006-2017")
# Out:
# Text(0.5, 1.0, 'Occurrences of Crimes Committed in Brooklyn 2006-2017')

# %%
manhattan_filter = nyc[nyc['BORO_NM'] == 'MANHATTAN']

# %%
manhattan_OFNS = manhattan_filter.groupby(['OFNS_DESC']).size().sort_values(ascending=False)
manhattan_OFNS
# Out:
# OFNS_DESC
# PETIT LARCENY                      336698
# GRAND LARCENY                      217630
# HARRASSMENT 2                      162372
# ASSAULT 3 & RELATED OFFENSES       130959
# CRIMINAL MISCHIEF & RELATED OF     120231
#                                     ...
# KIDNAPPING AND RELATED OFFENSES         2
# OFFENSES AGAINST MARRIAGE UNCL          2
# KIDNAPPING                              1
# UNDER THE INFLUENCE OF DRUGS            1
# LOITERING/DEVIATE SEX                   1
# Length: 67, dtype: int64

# %%
sns.set(rc={"figure.figsize":(20,20)})
ax = sns.countplot(data=manhattan_filter, x=manhattan_filter['OFNS_DESC'])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax= plt.gca()
ax.set_title("Occurrences of Crimes Committed in Manhattan 2006-2017")
# Out:
# Text(0.5, 1.0, 'Occurrences of Crimes Committed in Manhattan 2006-2017')

# %%
bronx_filter = nyc[nyc['BORO_NM'] == 'BRONX']

# %%
bronx_OFNS = bronx_filter.groupby(['OFNS_DESC']).size().sort_values(ascending=False)
bronx_OFNS
# Out:
# OFNS_DESC
# PETIT LARCENY                     184969
# HARRASSMENT 2                     175954
# ASSAULT 3 & RELATED OFFENSES      167377
# DANGEROUS DRUGS                   151279
# CRIMINAL MISCHIEF & RELATED OF    135595
#                                    ...
# OTHER TRAFFIC INFRACTION               1
# OFFENSES AGAINST MARRIAGE UNCL         1
# FORTUNE TELLING                        1
# ADMINISTRATIVE CODES                   1
# ABORTION                               1
# Length: 67, dtype: int64

# %%
sns.set(rc={"figure.figsize":(20,20)})
ax = sns.countplot(data=bronx_filter, x=bronx_filter['OFNS_DESC'])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax= plt.gca()
ax.set_title("Occurrences of Crimes Committed in The Bronx 2006-2017")
# Out:
# Text(0.5, 1.0, 'Occurrences of Crimes Committed in The Bronx 2006-2017')

# %%
queens_filter = nyc[nyc['BORO_NM'] == 'QUEENS']

# %%
queens_OFNS = queens_filter.groupby(['OFNS_DESC']).size().sort_values(ascending=False)
queens_OFNS
# Out:
# OFNS_DESC
# PETIT LARCENY                       207461
# HARRASSMENT 2                       168773
# CRIMINAL MISCHIEF & RELATED OF      150694
# ASSAULT 3 & RELATED OFFENSES        136508
# GRAND LARCENY                       106766
#                                      ...
# ABORTION                                 4
# FORTUNE TELLING                          2
# OTHER STATE LAWS (NON PENAL LAW)         1
# LOITERING FOR DRUG PURPOSES              1
# UNDER THE INFLUENCE OF DRUGS             1
# Length: 67, dtype: int64

# %%
sns.set(rc={"figure.figsize":(20,20)})
ax = sns.countplot(data=queens_filter, x=queens_filter['OFNS_DESC'])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax= plt.gca()
ax.set_title("Occurrences of Crimes Committed in Queens 2006-2017")
# Out:
# Text(0.5, 1.0, 'Occurrences of Crimes Committed in Queens 2006-2017')

# %%
staten_filter = nyc[nyc['BORO_NM'] == 'STATEN ISLAND']

# %%
staten_OFNS = staten_filter.groupby(['OFNS_DESC']).size().sort_values(ascending=False)
staten_OFNS
# Out:
# OFNS_DESC
# HARRASSMENT 2                           58281
# PETIT LARCENY                           47209
# CRIMINAL MISCHIEF & RELATED OF          43270
# ASSAULT 3 & RELATED OFFENSES            29629
# OFF. AGNST PUB ORD SENSBLTY &           23163
# GRAND LARCENY                           15049
# DANGEROUS DRUGS                         13069
# OFFENSES AGAINST PUBLIC ADMINI           8443
# BURGLARY                                 8215
# INTOXICATED & IMPAIRED DRIVING           8183
# FELONY ASSAULT                           7403
# MISCELLANEOUS PENAL LAW                  6551
# ROBBERY                                  5512
# DANGEROUS WEAPONS                        5315
# GRAND LARCENY OF MOTOR VEHICLE           4336
# THEFT-FRAUD                              4319
# FRAUDS                                   3457
# SEX CRIMES                               2699
# VEHICLE AND TRAFFIC LAWS                 2041
# CRIMINAL TRESPASS                        1842
# ...

# %%
sns.set(rc={"figure.figsize":(20,20)})
ax = sns.countplot(data=staten_filter, x=staten_filter['OFNS_DESC'])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
ax= plt.gca()
ax.set_title("Occurrences of Crimes Committed in Staten Island 2006-2017")
# Out:
# Text(0.5, 1.0, 'Occurrences of Crimes Committed in Staten Island 2006-2017')
